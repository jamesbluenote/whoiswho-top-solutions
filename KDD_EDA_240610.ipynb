# %%
from google.colab import drive
drive.mount('./gdrive')
# Out:
# Mounted at ./gdrive

# %%
import os

file_path = '/content/gdrive/MyDrive/whoiswho-top-solutions/incorrect_assignment_detection/GCCAD/IND-WhoIsWho'

os.chdir(file_path)
os.getcwd()
# Out:
# '/content/gdrive/MyDrive/whoiswho-top-solutions/incorrect_assignment_detection/GCCAD/IND-WhoIsWho'

# %%
import pandas as pd
import json as js

# %%
with open('train_author.json', 'r') as f:
    data = js.load(f)

train_author = pd.DataFrame(data)
train_author
# Out:
#                                                       Iki037dt  \
# name                                            atsushi ochiai
# normal_data  [YzOCpPTO, AblgcGjH, B5aouLse, u1G7wBEv, W7w6P...
# outliers     [XL3wd3CP, BTKTiJp2, JxSjl5xc, 0jyMLgRt, uHWx8...
#
#                                                       ZihzMro7  \
# name                                               mingwu yang
# normal_data  [C58t0yYu, sWIRnfR3, HJW8h2mo, 0Ptx4O5n, fU4vB...
# outliers     [qK8llKzD, I0eTdaAG, nFebDDiR, 903CyaNQ, Q45WM...
#
#                                                       WXMYBk3c  \
# name                                            jianzhao huang
# normal_data  [lJAIOXO4, fYJcce0K, ZaeOFAcI, kg9xDSXm, T37S3...
# outliers     [HwaUxOes, nvELwvhl, 6Z6SRTQh, R1yeZqOY, qnwco...
#
#                                                       WrCODHhe  \
# name                                               xuebiao yao
# normal_data  [3fYoJb1W, wjt8Y8ho, pPx6o7KZ, xgRarLPn, 9w9yz...
# ...

# %%
with open('ind_valid_author.json', 'r') as f:
    data = js.load(f)

valid_author = pd.DataFrame(data)
valid_author
# Out:
#                                                  efQ8FQ1i  \
# name                                            chen dong
# papers  [cGvhkZHC, MmRHIvd2, agExpryu, eBrOqu4i, WEz1t...
#
#                                                  C97iQ0Fj  \
# name                                       xiangquan kong
# papers  [16grt2XV, ddYPEbL2, 4RUXj0dp, bgq0ZUiD, G7me8...
#
#                                                  VvKR94tE  \
# name                                       stephen bonner
# papers  [z9tBeZpB, LBF8V0R7, ve4cZSnG, 4SZH6NMu, jx9x9...
#
#                                                  UF2hch6j  \
# name                                           heping cao
# papers  [4Nf5UZBl, zdlvVxoB, L7JbQRWL, ehQ9lY2R, qd1JH...
#
#                                                  xb6tyRp8  \
# name                                 siddhartha chaudhuri
# papers  [ApK8dQmd, oyAtP5qN, 0O83Pooh, 47g7LjvL, 9o8wv...
#
#                                                  ZUKuSTRt  \
# ...

# %%
with open('ind_valid_author_submit.json', 'r') as f:
    data = js.load(f)

valid_author_sub = pd.DataFrame(data)
valid_author_sub
# Out:
#           efQ8FQ1i  C97iQ0Fj  VvKR94tE  UF2hch6j  xb6tyRp8  ZUKuSTRt  \
# cGvhkZHC       0.5       NaN       NaN       NaN       NaN       NaN
# MmRHIvd2       0.5       NaN       NaN       NaN       NaN       NaN
# agExpryu       0.5       NaN       NaN       NaN       NaN       NaN
# eBrOqu4i       0.5       NaN       NaN       NaN       NaN       NaN
# WEz1t7hC       0.5       NaN       NaN       NaN       NaN       NaN
# ...            ...       ...       ...       ...       ...       ...
# lN8IseWJ       NaN       NaN       NaN       NaN       NaN       NaN
# YJX2mCGA       NaN       NaN       NaN       NaN       NaN       NaN
# 5354bUPk       NaN       NaN       NaN       NaN       NaN       NaN
# SsvAuBAH       NaN       NaN       NaN       NaN       NaN       NaN
# L240KxTG       NaN       NaN       NaN       NaN       NaN       NaN
#
#           NVN2xX3I  kcIq8Zfh  dYhCnhNk  q1NXVO7P  ...  VWeoHG7i  IB40U5VJ  \
# ...
